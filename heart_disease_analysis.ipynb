# %% [markdown]
# ### 1. Import the libraries and dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heartdata=pd.read_csv(r"C:\Users\HP\Downloads\heart.csv")

# %% [markdown]
# ### 2. display Top 5 Rows and last 5 rows of the dataset

# %%
heartdata
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### 3. Find the shape of our dataset(number of rows and number of columns)

# %%
heartdata.shape
# Out:
# (1025, 14)

# %% [markdown]
# ### 4. Get information about the dataset like the total number of rows and columns the Datatypes of each column and the memory requirement

# %%
heartdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# ### 5. Check for Null Values in the Dataset

# %%
heartdata.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### 6.Check For Duplicate Data and Drop Them

# %%
# if output is True, then there's some duplicates
heart_dup=heartdata.duplicated().any()
print(heart_dup)
# Out:
# True

# %%
heartdata = heartdata.drop_duplicates()

# %%
heartdata.shape
# Out:
# (302, 14)

# %% [markdown]
# ### 7. Get the overall statistics about the dataset

# %%
heartdata.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ### 8. Draw Correlation Matrix

# %%
# to check correlation between different features available in our dataset
plt.figure(figsize=(13,7))
sns.heatmap(heartdata.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 9. how Many People Have Heart Disease, and How Many Don't Have Heart Disease

# %%
heartdata.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heartdata['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x =heartdata['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# ### 10. Find Count of Male & Female in this dataset

# %%
heartdata.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heartdata['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
# use countplot to visualize it

sns.countplot(x= heartdata['sex'])
# let me change this x labelS.[0,1] is replaced by ['Female','Male']
plt.xticks([0,1],['Female','Male'])
plt.show()

# %% [markdown]
# ### 11. Finding Gender distribution according to the target variable

# %%
sns.countplot(x='sex',hue='target',data=heartdata)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No Disease','Disease'])
plt.show()

# %% [markdown]
# ### 12. Check Age Distribution in the Dataset

# %%
sns.histplot(heartdata['age'], bins=20, kde=True)
plt.show()

# %%
 #From the graph above it shows that most people are between the ages of 50 and 60.

# %% [markdown]
# # 13. Which chest pain type is more common

# %%
sns.countplot(x='cp', hue='cp', data=heartdata, palette=['Blue', 'Red', 'Orange', 'Green'], legend=False)
plt.xticks([0, 1, 2, 3], ["typical aginal", "atypical aginal", "non-aginal pain", "asymptomatic"])
plt.xticks(rotation=0)
plt.show()

# %%
  # From the above countplot we can see that the most common type of chest pain is the typical aginal chest pain

# %% [markdown]
# ### 14. Show the chest pain distribution as per target variable

# %%
sns.countplot(x='cp',hue='target',data=heartdata)
plt.legend(labels=['No Disease','Disease'])
plt.show()

# %%
# from the graph above we can see that healthy people also have chest pain
#chest paincan be subjective due to stress, physical activities etc.
# it varies between gender

# %% [markdown]
# ### 15. Show the Fasting blood sugar distribution according to target variable

# %%
sns.countplot(x='fbs',hue='target',data=heartdata)
plt.legend(labels=['No Disease','Disease'])
plt.show()

# %%
# fbs is a diabetic indicator
# fbs greater than 120 are diabetics
# higher number of diabetics patients without heart disease

# %% [markdown]
# ### 16. Checking resting blood pressure distribution

# %%
# lets create a histogram
heartdata['trestbps'].hist()
# Out:
# <Axes: >

# %%
# from the histogram above we can see that people in this study have a blood pressure between 120 and 140

# %% [markdown]
# ### 17. Compare Resting blood pressure per sex column

# %%
g= sns.FacetGrid(heartdata, hue="sex", aspect=4)
g.map(sns.kdeplot,'trestbps', fill=True)
plt.legend(labels=['Male','Female'])

# %%
# from the diagram above it shows that females have lower blood pressure tham males
#for females bps is around 120 while for males it is a little less than 140

# %% [markdown]
# ### 18. Show distribution of Serum Cholesterol

# %%
# we'll use a histogram toshow to check distribution of serum cholesterol
heartdata['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### 19. Plot continuous variables

# %%
#In this question we are going to plot continuous variables.
# first we have to separate columns which contain continuous values and categorical values

# %%
heartdata.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# lets create an empty list
categ_val=[]
cont_val=[]
for column in heartdata.columns:
    if heartdata[column].nunique() <=10:
        categ_val.append(column)
    else: 
        cont_val.append(column)

# %%
categ_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
heartdata.hist(cont_val,figsize=(10,10))
plt.tight_layout()
plt.show()
